# %%
from numpy import *
from matplotlib import pyplot as plt

# %%
def magsq(z):
    return z.real**2 + z.imag**2

# %%
def psi_100(x, y, z, Z=1, a0=1):
    r = sqrt(x**2 + y**2 + z**2)
    return 1/(sqrt(pi)) * (Z/a0)**(3/2) * exp(-Z*r/(a0))
def psi_200(x, y, z, Z=1, a0=1):
    r = sqrt(x**2 + y**2 + z**2)
    return 1/sqrt(pi) * (Z/(2*a0))**(3/2) * (1 - (Z*r/(2*a0))) * exp(-Z*r/(2*a0))
def psi_210(x, y, z, Z=1, a0=1):
    r = sqrt(x**2 + y**2 + z**2)
    return 1/(2*sqrt(pi)) * (Z/(2*a0))**(3/2) * (Z*r/a0) * exp(-Z*r/(2*a0)) * (z/r)
def psi_21p1(x, y, z, Z=1, a0=1):
    r = sqrt(x**2 + y**2 + z**2)
    theta = arctan(sqrt(x**2 + y**2)/z)
    phi = arctan(y/x)
    return -1/(2*sqrt(2*pi)) * (Z/(2*a0))**(3/2) * (Z*r/a0) * exp(-Z*r/(2*a0)) * sin(theta) * exp(1j*phi)
def psi_21n1(x, y, z, Z=1, a0=1):
    r = sqrt(x**2 + y**2 + z**2)
    theta = arctan(sqrt(x**2 + y**2)/z)
    phi = arctan(y/x)
    return 1/(2*sqrt(2*pi)) * (Z/(2*a0))**(3/2) * (Z*r/a0) * exp(-Z*r/(2*a0)) * sin(theta) * exp(-1j*phi)
def psi_300(x, y, z, Z=1, a0=1):
    r = sqrt(x**2 + y**2 + z**2)
    theta = arctan(sqrt(x**2 + y**2)/z)
    phi = arctan(y/x)
    return 1/sqrt(pi) * (Z/(3*a0))**(3/2) * (1-2*Z*r/(3*a0) + 2/27*(Z*r/a0)**2) * exp(-Z*r/(3*a0))
def psi_310(x, y, z, Z=1, a0=1):
    r = sqrt(x**2 + y**2 + z**2)
    theta = arctan(sqrt(x**2 + y**2)/z)
    phi = arctan(y/x)
    return 2*sqrt(2)/(3*sqrt(3*pi)) * (Z/(3*a0))**(3/2) * Z*r/a0 * (1-Z*r/(6*a0)) * exp(-Z*r/(3*a0)) * (z/r)
def psi_31p1(x, y, z, Z=1, a0=1):
    r = sqrt(x**2 + y**2 + z**2)
    theta = arctan(sqrt(x**2 + y**2)/z)
    phi = arctan(y/x)
    return -2/(3*sqrt(3*pi)) * (Z/(3*a0))**(3/2) * Z*r/a0 * (1-Z*r/(6*a0)) * exp(-Z*r/(3*a0)) * sin(theta) * exp(1j*phi)
def psi_31n1(x, y, z, Z=1, a0=1):
    r = sqrt(x**2 + y**2 + z**2)
    theta = arctan(sqrt(x**2 + y**2)/z)
    phi = arctan(y/x)
    return 2/(3*sqrt(3*pi)) * (Z/(3*a0))**(3/2) * Z*r/a0 * (1-Z*r/(6*a0)) * exp(-Z*r/(3*a0)) * sin(theta) * exp(-1j*phi)
def psi_320(x, y, z, Z=1, a0=1):
    r = sqrt(x**2 + y**2 + z**2)
    theta = arctan(sqrt(x**2 + y**2)/z)
    phi = arctan(y/x)
    return 1/(27*sqrt(2*pi)) * (Z/(3*a0))**(3/2) * (Z*r/a0)**2 * exp(-Z*r/(3*a0)) *(3*(z/r)**2-1)
def psi_32p1(x, y, z, Z=1, a0=1):
    r = sqrt(x**2 + y**2 + z**2)
    theta = arctan(sqrt(x**2 + y**2)/z)
    phi = arctan(y/x)
    return -sqrt(3)/(27*sqrt(pi)) * (Z/(3*a0))**(3/2) * (Z*r/a0)**2 * exp(-Z*r/(3*a0)) *sin(theta) * (z/r) * exp(1j*phi)
def psi_32n1(x, y, z, Z=1, a0=1):
    r = sqrt(x**2 + y**2 + z**2)
    theta = arctan(sqrt(x**2 + y**2)/z)
    phi = arctan(y/x)
    return sqrt(3)/(27*sqrt(pi)) * (Z/(3*a0))**(3/2) * (Z*r/a0)**2 * exp(-Z*r/(3*a0)) *sin(theta) * (z/r) * exp(-1j*phi)
def psi_32p2(x, y, z, Z=1, a0=1):
    r = sqrt(x**2 + y**2 + z**2)
    theta = arctan(sqrt(x**2 + y**2)/z)
    phi = arctan(y/x)
    return sqrt(3)/(54*sqrt(pi)) * (Z/(3*a0))**(3/2) * (Z*r/a0)**2 * exp(-Z*r/(3*a0)) * sin(theta)**2*exp(2j*phi)
def psi_32n1(x, y, z, Z=1, a0=1):
    r = sqrt(x**2 + y**2 + z**2)
    theta = arctan(sqrt(x**2 + y**2)/z)
    phi = arctan(y/x)
    return sqrt(3)/(54*sqrt(pi)) * (Z/(3*a0))**(3/2) * (Z*r/a0)**2 * exp(-Z*r/(3*a0)) * sin(theta)**2*exp(-2j*phi)

def psi(x, y, z,functions, weights, phases, Z=1, a0=1):
    wave = 0
    for state, weight, phase in zip(functions, weights, phases):
        wave += sqrt(weight) * exp(1j*phase) * state(x, y, z, Z, a0)
    return magsq(wave)
  
#     return magsq(sqrt(4/5)*psi_200(x,y,z) + exp(1j*alpha)*sqrt(1/5)*psi_210(x,y,z))

# %%
dom = linspace(-10, 10, 1000)
x, z = meshgrid(dom, dom)

# %%
f = [psi_32p1, psi_320, psi_300]
w = [1, 1, 1]
p = [pi, 0, 0]

# %%
w = w/array(w).sum()
test = psi(x, 0, z, f, w, p)
plt.figure(figsize=(5,5))
plt.pcolormesh(x, z, test, cmap='gray',  vmin=0, vmax=0.0005)

# %%
plt.figure(figsize=(10,5))
ax = plt.subplot(1,2,1)
ax.pcolormesh(x, z,  magsq(psi_200(x, 0, z)), cmap='gray',  vmin=0, vmax=0.0014)
ax = plt.subplot(1,2,2)
ax.pcolormesh(x, z,  magsq(psi_210(x, 0, z)), cmap='gray',  vmin=0, vmax=0.0014)
plt.show()

# %%
plt.figure(figsize=(10,10))
for i, alpha in enumerate([0, pi/4, pi/3, pi/2]):
    ax = plt.subplot(2,2,i+1)
    ax.pcolormesh(x, z, psi(x, 0, z, alpha), cmap='gray',  vmin=0, vmax=0.0014)
